# %% [markdown]
# # Euro Exchange Project
#
# The dataset we'll use describes Euro daily exchange rates between 1999 and 2022. The euro (symbolized with €) is the official currency in most of the countries of the European Union.
#
# If the exchange rate of the euro to the US dollar is 1.5, you get 1.5 US dollars if you pay 1.0 euro (one euro has more value than one US dollar at this exchange rate).
#
# Our focus in the guided part of the project will be on the exchange rate between the euro and the American dollar.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/euro-daily-hist_1999_2022.csv')
df.head()
# Out:
#   Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 0   2023-05-26               1.6439           1.9558            5.3878
# 1   2023-05-25               1.6443           1.9558            5.3320
# 2   2023-05-24               1.6402           1.9558            5.3397
# 3   2023-05-23               1.6282           1.9558            5.3649
# 4   2023-05-22               1.6294           1.9558            5.4056
#
#   [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ] [Cypriot pound ]  \
# 0             1.4630         0.9707                   7.5874              NaN
# 1             1.4599         0.9708                   7.5891              NaN
# 2             1.4600         0.9732                   7.6005              NaN
# 3             1.4571         0.9718                   7.6039              NaN
# 4             1.4618         0.9700                   7.6067              NaN
#
# ...

# %%
df.tail()
# Out:
#      Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 6306   1999-01-08               1.8406              NaN               NaN
# 6307   1999-01-07               1.8474              NaN               NaN
# 6308   1999-01-06               1.8820              NaN               NaN
# 6309   1999-01-05               1.8944              NaN               NaN
# 6310   1999-01-04               1.9100              NaN               NaN
#
#      [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ]  \
# 6306             1.7643         1.6138                      NaN
# 6307             1.7602         1.6165                      NaN
# 6308             1.7711         1.6116                      NaN
# 6309             1.7965         1.6123                      NaN
# 6310             1.8004         1.6168                      NaN
#
#      [Cypriot pound ] [Czech koruna ] [Danish krone ]  ... [Romanian leu ]  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6311 entries, 0 to 6310
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Period\Unit:              6311 non-null   object
#  1   [Australian dollar ]      6311 non-null   object
#  2   [Bulgarian lev ]          5909 non-null   object
#  3   [Brazilian real ]         6043 non-null   object
#  4   [Canadian dollar ]        6311 non-null   object
#  5   [Swiss franc ]            6311 non-null   object
#  6   [Chinese yuan renminbi ]  6043 non-null   object
#  7   [Cypriot pound ]          2346 non-null   object
#  8   [Czech koruna ]           6311 non-null   object
#  9   [Danish krone ]           6311 non-null   object
#  10  [Estonian kroon ]         3130 non-null   object
#  11  [UK pound sterling ]      6311 non-null   object
#  12  [Greek drachma ]          520 non-null    object
# ...

# %% [markdown]
# Although, the total number of row is 6311 and number of columns is 41, some columns have missing values.
#
# Even though all columns are about numbers, some of them are as objects and other as float.
#
# ---

# %% [markdown]
# ### Data Cleaning
# We will rename the '[US dollar]' columns and 'Period\Unit:' columns to make it easier to work with.

# %%
df.columns
# Out:
# Index(['Period\Unit:', '[Australian dollar ]', '[Bulgarian lev ]',
#        '[Brazilian real ]', '[Canadian dollar ]', '[Swiss franc ]',
#        '[Chinese yuan renminbi ]', '[Cypriot pound ]', '[Czech koruna ]',
#        '[Danish krone ]', '[Estonian kroon ]', '[UK pound sterling ]',
#        '[Greek drachma ]', '[Hong Kong dollar ]', '[Croatian kuna ]',
#        '[Hungarian forint ]', '[Indonesian rupiah ]', '[Israeli shekel ]',
#        '[Indian rupee ]', '[Iceland krona ]', '[Japanese yen ]',
#        '[Korean won ]', '[Lithuanian litas ]', '[Latvian lats ]',
#        '[Maltese lira ]', '[Mexican peso ]', '[Malaysian ringgit ]',
#        '[Norwegian krone ]', '[New Zealand dollar ]', '[Philippine peso ]',
#        '[Polish zloty ]', '[Romanian leu ]', '[Russian rouble ]',
#        '[Swedish krona ]', '[Singapore dollar ]', '[Slovenian tolar ]',
#        '[Slovak koruna ]', '[Thai baht ]', '[Turkish lira ]', '[US dollar ]',
#        '[South African rand ]'],
# ...

# %%
df.rename(columns={'[US dollar ]': 'US_dollar',
                               'Period\\Unit:': 'Time'}, #pay attention here tow inverted dashes
                      inplace=True)

df['Time'] = pd.to_datetime(df['Time'])
df.sort_values('Time', inplace=True) #sorting values
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#         Time [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 0 1999-01-04               1.9100              NaN               NaN
# 1 1999-01-05               1.8944              NaN               NaN
# 2 1999-01-06               1.8820              NaN               NaN
# 3 1999-01-07               1.8474              NaN               NaN
# 4 1999-01-08               1.8406              NaN               NaN
#
#   [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ] [Cypriot pound ]  \
# 0             1.8004         1.6168                      NaN          0.58231
# 1             1.7965         1.6123                      NaN          0.58230
# 2             1.7711         1.6116                      NaN          0.58200
# 3             1.7602         1.6165                      NaN          0.58187
# 4             1.7643         1.6138                      NaN          0.58187
#
#   [Czech koruna ] [Danish krone ]  ... [Romanian leu ] [Russian rouble ]  \
# ...

# %% [markdown]
# Isolating the 'Time' and the 'US_dollar' columns:

# %%
euro_to_dollar = df[['Time', 'US_dollar']].copy()
df['US_dollar'].value_counts()
# Out:
# -         62
# 1.2276     9
# 1.1215     8
# 1.1268     7
# 1.1305     7
#           ..
# 1.4030     1
# 1.4113     1
# 1.4106     1
# 1.4127     1
# 1.0751     1
# Name: US_dollar, Length: 3734, dtype: int64

# %%
#dropping the values that start with '-' and transforming it to float
euro_to_dollar = euro_to_dollar[euro_to_dollar['US_dollar'] != '-']
euro_to_dollar['US_dollar'] = euro_to_dollar['US_dollar'].astype(float)
euro_to_dollar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6249 entries, 0 to 6310
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Time       6249 non-null   datetime64[ns]
#  1   US_dollar  6249 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 146.5 KB

# %% [markdown]
# ### Roling Mean

# %%
euro_to_dollar['rolling_mean'] = euro_to_dollar['US_dollar'].rolling(30).mean()
euro_to_dollar
# Out:
#            Time  US_dollar  rolling_mean
# 0    1999-01-04     1.1789           NaN
# 1    1999-01-05     1.1790           NaN
# 2    1999-01-06     1.1743           NaN
# 3    1999-01-07     1.1632           NaN
# 4    1999-01-08     1.1659           NaN
# ...         ...        ...           ...
# 6306 2023-05-22     1.0822      1.095337
# 6307 2023-05-23     1.0779      1.094883
# 6308 2023-05-24     1.0785      1.094483
# 6309 2023-05-25     1.0735      1.093860
# 6310 2023-05-26     1.0751      1.092980
#
# [6249 rows x 3 columns]

# %%
plt.plot(euro_to_dollar['Time'], euro_to_dollar['US_dollar'])
plt.show()

# %% [markdown]
# ### Coming up with an Idea

# %% [markdown]
# How the euro-dollar rate has changed during the coronavirus pandemic  compared to previous years.

# %%
#separating the years
euro_to_dollar['year'] = euro_to_dollar['Time'].dt.year

previous_year = euro_to_dollar.copy()[(euro_to_dollar['year'] >= 2016) & (euro_to_dollar['year'] < 2020)]
print(previous_year.shape)

pandemic_year = euro_to_dollar.copy()[(euro_to_dollar['year'] >= 2020)]
print(pandemic_year.shape)
# Out:
# (1022, 4)
# (874, 4)

# %% [markdown]
# ## Euro_Dollar exchange rate during **COVID-19**:

# %%
#FiveThirtyEight style
import matplotlib.style as style
style.use('fivethirtyeight')

#Adding the plot
fig, ax = plt.subplots(figsize=(8,3))
ax.plot(previous_year['Time'],
        previous_year['rolling_mean'],
        linewidth=1, color='#A6D785'
        )

#Highlighting the year of the pandemy
ax.plot(pandemic_year['Time'],
        pandemic_year['rolling_mean'],
        linewidth=3, color='#e23d28',
        )

#Highlight the peak of pandemy
ax.axvspan(xmin=18580, xmax=18870, ymin=.09,
           alpha=.3, color='grey')


ax.text(16500.0, 1.3, 'Euro-USD rate peaked at 1.22 during 2019-2022´s Covid-19 pandemic',
        weight='bold', size=12)
ax.text(16500.0, 1.27, 'Euro-USD exchange rates between 2016 and 2023',
      size=12)

ax.tick_params(axis='x', colors='grey')
ax.tick_params(axis='y', colors='grey')

#Adding signature
ax.text(16500, .9, 'Henrique Araujo' +' '*55 + 'Source: European Central Bank',
        color='#f0f0f0', backgroundcolor='#4d4d4d')
plt.show()

# %% [markdown]
# Apparently the covid itself did not interfer that much in the Euro-Dollar exchange rate. I thought the COVID-19 situation would change drastically the Euro-USD exchange rates, but aparrently it doesn´t.

# %% [markdown]
# ## Financial Crisis Graphic:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Separating the crisis from normal date
financial_crisis = euro_to_dollar.copy()[(euro_to_dollar['Time'].dt.year >= 2006
                                         ) & (euro_to_dollar['Time'].dt.year <= 2009)]

financial_crisis_7_8 = euro_to_dollar.copy()[(euro_to_dollar['Time'].dt.year >= 2007
                                              ) & (euro_to_dollar['Time'].dt.year <= 2008)]

# %%
#Adding the plot
fig, ax = plt.subplots(figsize=(8,3))
ax.plot(financial_crisis['Time'],
        financial_crisis['rolling_mean'],
        linewidth=1, color='#A6D785'
        )

#Highlighting the year of the pandemy
ax.plot(financial_crisis_7_8['Time'],
        financial_crisis_7_8['rolling_mean'],
        linewidth=3, color='#e23d28',
        )
### Highlihting the peak of the crisis
ax.axvspan(xmin=13950, xmax=14150, ymin=.09,
           alpha=.3, color='grey')

#Adding separate tick labels
ax.set_xticklabels([])
ax.set_yticklabels([])

x=13100
for year in ['2006', '2007', '2008', '2009', '2010']:
  ax.text(x, 1.13, year, alpha=.5, fontsize=11)
  x += 365

y = 1.197
for rate in ['1.2', '1.3', '1.4', '1.5']:
    ax.text(13000, y, rate, alpha=0.5, fontsize=11)
    y += 0.1

#Adding title and subtitle
ax.text(13000, 1.67, "Euro-USD rate peaked at 1.59 during 2007-2008's financial crisis",
   weight='bold')

ax.text(13000, 1.63, 'Euro-USD exchange rates between 2006 and 2010', size = 12)

#Adding signature
ax.text(13000, 1.08, 'Henrique Araujo' + ' '*94 + 'Source: European Central Bank',
        color='#f0f0f0', backgroundcolor = '#4d4d4d',
        size=10)

#Add some transparency to the grid
ax.grid(alpha=.5)

plt.show()

# %% [markdown]
# By analyzing the graph, we can notice that after the 2007-2008´s economic crisis in USA, that was a significant increase in the Euro-USD exchange rate, due to the worsening of America´s economy.

# %% [markdown]
# ## The Three US Presidencies Graphic:

# %%
#Separating the presidents by their mandate
three_presid = euro_to_dollar.copy()[(euro_to_dollar['Time'].dt.year >= 2001) & (euro_to_dollar['Time'].dt.year < 2022)]

bush = three_presid.copy()[(three_presid['Time'].dt.year < 2009)]

obama = three_presid.copy()[(three_presid['Time'].dt.year >= 2009) & (three_presid['Time'].dt.year < 2017)]

trump = three_presid.copy()[(three_presid['Time'].dt.year >= 2017) & (three_presid['Time'].dt.year < 2021)]

# %%
style.use('fivethirtyeight')

#Adding subplots
plt.figure(figsize=(12,6))
ax1= plt.subplot(2,3,1)
ax2= plt.subplot(2,3,2)
ax3= plt.subplot(2,3,3)
ax4= plt.subplot(2,1,2)
axes = [ax1, ax2, ax3, ax4]

#Changes to all the subplots
#Creating a pattern for all the plots
for ax in axes:
  ax.set_ylim(.8, 1.7) #setting the size of the y
  ax.set_yticks([1.0, 1.2, 1.4, 1.6])
  ax.set_yticklabels(['1.0', '1.2', '1.4', '1.6'],
                     alpha=.3)
  ax.grid(alpha=.5)

#Ax1: Bush
ax1.plot(bush['Time'], bush['rolling_mean'],
         color='#BF5FFF')
ax1.set_xticklabels(['', '2001','', '2003','', '2005', '',
                     '2007', '', '2009'],
                    alpha=.3)
#Adding title and subtitle
ax1.text(12400, 1.85, 'BUSH', fontsize=18, weight='bold',
         color='#BF5FFF')
ax1.text(12200, 1.75, '2001-2009', weight='bold',
         alpha=.3)


#Ax2: Obama
ax2.plot(obama['Time'], obama['rolling_mean'],
        color='#ffa500')
ax2.set_xticklabels(['','2009','','2011','','2013','',
                    '2015','','2017'],
                    alpha=.3)
#Adding title and subtitle
ax2.text(15200, 1.85, 'OBAMA', fontsize=18, weight='bold',
         color='#ffa500')
ax2.text(15150, 1.75, '2009-2017', weight='bold',
         alpha=.3)

#Ax3: Trump
ax3.plot(trump['Time'], trump['rolling_mean'],
         color='#00B2EE')
ax3.set_xticklabels(['2017','','2018','','2019','',
                     '2020','','2021'],
                    alpha=.3)
#Adding title and subtitle
ax3.text(17660, 1.85, 'TRUMP', fontsize=18, weight='bold',
         color='#00B2EE')
ax3.text(17600, 1.75, '2017-2021', weight='bold',
         alpha=.3)

#Creating graphic of the three presidents
#Ax4: All
ax4.plot(bush['Time'], bush['rolling_mean'],
         color='#BF5FFF')
ax4.plot(obama['Time'], obama['rolling_mean'],
         color='#ffa500')
ax4.plot(trump['Time'], trump['rolling_mean'],
         color='#00B2EE')
ax4.grid(alpha=.5)
ax4.set_xticks([])

#Adding title and subtitle for the entire graphic:
ax1.text(10800, 2.27, 'EURO-USD rate averaged 1.22 under the last three US presidents',
         fontsize=20, weight='bold')
ax1.text(10800, 2.07, '''EURO-USD rates under Geroge W. Bush (2001 - 2009), Barack Obama(2009 - 2017) and
Donald Trump (2017-2021)''',
         fontsize=16)

#Adding my signature
ax4.text(10650, 0.65, 'Henrique Araujo' + ' '*112 + 'Source: European Central Bank',
         color='#f0f0f0', backgroundcolor ='#4d4d4d',
         size=14)
plt.show()
# Out:
# <ipython-input-85-d021eacb7eae>:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(['', '2001','', '2003','', '2005', '',
# <ipython-input-85-d021eacb7eae>:36: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(['','2009','','2011','','2013','',
# <ipython-input-85-d021eacb7eae>:48: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(['2017','','2018','','2019','',

# %% [markdown]
# ## Conclusion:
#
# * **Bush** started with a great economy, the Dollar worthing more than the Euro, but ended his mandate terribly after the 2007-2008´s economic crisis, having its peak at **USD1.59**.
#
# * **Obama** assumed the position and incredibly made "America Great Again" in terms of economy, bringing the difference from **USD1.37** to **USD1.14**.
#
# * **Trump** seems to have had the most constant economy, not a lot of ups and downs.
#
# Although Trump had a stable economy throughout his mandate, **OBAMA** appears to be better than the other two when it comes to Euro-USD exchange rate.
